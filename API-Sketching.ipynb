# %%
import pathlib
import matplotlib.pyplot as plt

from ml4paleo.volume_providers import ImageStackVolumeProvider
from ml4paleo.segmentation import UNetSegmentation

# %%
isv = ImageStackVolumeProvider(pathlib.Path("/Users/mateljk1/Documents/projects/tanis/data/Paddlefish 43.53 um/Bones 43.53 um"))

# %%
isv.shape
# Out:
# (1771, 1117, 3193)

# %%
plt.imshow(isv[:,:, 1000], cmap="gray")
# Out:
# (1000, 1001) (0, 1117) (0, 3193)
# (1117, 1771, 1)

# %%
UNetSegmentation().segment(isv[:128, :128, :128])
# Out:
# (0, 128) (0, 128) (0, 128)
# (1117, 1771, 128)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 UNetSegmentation().segment(isv[:128, :128, :128])
#
# File ~/Documents/projects/ml4paleo/ml4paleo/segmentation/__init__.py:118, in UNetSegmentation.segment(self, volume)
#     116 with torch.no_grad():
#     117     volume = torch.from_numpy(volume).unsqueeze(0).unsqueeze(0).float()
# --> 118     mask = F.softmax(model(volume), dim=1).argmax(dim=1).squeeze(0).numpy()
#     120 return mask
#
# File ~/Documents/projects/ml4paleo/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/projects/ml4paleo/ml4paleo/segmentation/models/__init__.py:84, in UNet3D.forward(self, x)
#      82 for i in range(self.u_depth - 1):
#      83     x = F.interpolate(x, scale_factor=2, mode="trilinear", align_corners=False)
# ---> 84     x = torch.cat([x, encoder_outputs[self.u_depth - i - 2]], dim=1)
#      85     x = self.decoder[i](x)
#      87 # Run the output layer:
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 16 but got size 32 for tensor number 1 in the list.
